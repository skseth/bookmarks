# %% [markdown]
# # Web Standards

# %% [markdown]
# ## Browser Comparisons
#
# [Can i Use](http://caniuse.com/)

# %% [markdown]
# ## CSS Tools & Standards
#
# **Standards**
#
# [SaSS](http://sass-lang.com/)
#
# [Custom CSS Properties - by Philip Walton](http://philipwalton.com/articles/why-im-excited-about-native-css-variables/)
#
# **FlexBox**
#
# [A complete guide to FlexBox](https://css-tricks.com/snippets/css/a-guide-to-flexbox/)
#
# [Solved by FlexBox](https://github.com/philipwalton/solved-by-flexbox)
#
# **Libraries**
#
# [Pure.CSS](http://purecss.io/)
#
# [Bourbon](http://bourbon.io/) and [Neat](http://neat.bourbon.io/)
#
# [CSS Coding Style Guide from US Gov](https://pages.18f.gov/frontend/css-coding-styleguide/format/)

# %%
# %%HTML
# <style scoped>
#
# .u-textCenter {
#     text-align: center!important;
# }
#
# *, :after, :before {
#     box-sizing: border-box;
# }
#
#
# .Demo {
#     width: 100%;
#     padding: .8em 1em 0;
#     background: hsla(31,15%,50%,.1);
#     border-radius: 3px;
#     color: rgb(64,64,64);
#     font: 400 1em/1.4 'Open Sans',sans-serif;
#     font-size: 16px;
#     font-weight:300;
#     text-rendering: optimizeLegibility;
# }
#
# .Demo:after {
#     content: '\00a0';
#     display: block;
#     margin-top: 1em;
#     height: 0;
#     visibility: hidden;
# }
#
# .Grid {
#   display: flex;
#   flex-wrap: wrap;
#   list-style: none;
#   margin: 0;
#   padding: 0;
# }
#
#
# .Grid-cell {
#   flex: 1;
# }
#
#
# .Grid--flexCells > .Grid-cell {
#   display: flex;
# }
#
# .Grid--gutters {
#   margin: -1em 0 1em -1em;
# }
#
# .Grid--gutters>.Grid-cell {
#     padding: 1em 0 0 1em;
# }
#
# </style>
# <div class="Grid Grid--gutters u-textCenter">
#   <div class="Grid-cell">
#     <div class="Demo">1/3</div>
#   </div>
#   <div class="Grid-cell">
#     <div class="Demo">1/3</div>
#   </div>
#   <div class="Grid-cell">
#     <div class="Demo">1/3</div>
#   </div>
# </div>
# Out:
# <style scoped>
#
# .u-textCenter {
#     text-align: center!important;
# }
#
# *, :after, :before {
#     box-sizing: border-box;
# }
#
#
# .Demo {
#     width: 100%;
#     padding: .8em 1em 0;
#     background: hsla(31,15%,50%,.1);
#     border-radius: 3px;
#     color: rgb(64,64,64);
#     font: 400 1em/1.4 'Open Sans',sans-serif;
#     font-size: 16px;
#     font-weight:300;
#     text-rendering: optimizeLegibility;
# }
#
# .Demo:after {
#     content: '\00a0';
#     display: block;
#     margin-top: 1em;
#     height: 0;
#     visibility: hidden;
# }
#
# .Grid {
#   display: flex;
#   flex-wrap: wrap;
#   list-style: none;
#   margin: 0;
#   padding: 0;
# }
#
#
# .Grid-cell {
#   flex: 1;
# }
#
#
# .Grid--flexCells > .Grid-cell {
#   display: flex;
# }
#
# .Grid--gutters {
#   margin: -1em 0 1em -1em;
# }
#
# .Grid--gutters>.Grid-cell {
#     padding: 1em 0 0 1em;
# }
#
# </style>
# <div class="Grid Grid--gutters u-textCenter">
#   <div class="Grid-cell">
# ...
